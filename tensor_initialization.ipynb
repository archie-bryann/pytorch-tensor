# %%
import tensor

# %%
# my_tensor = torch.tensor([[1, 2, 3], [4, 5, 6]])
my_tensor = torch.tensor([[1, 2, 3], [4, 5, 6]], dtype=torch.float32,
                        device="cuda") # cpu, which is the default
print(my_tensor)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]], device='cuda:0')
